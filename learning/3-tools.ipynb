# %% [markdown]
# Tools

# %%
from langchain.tools import tool
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-3.5-flash-lite")

@tool
def get_weather(location: str) -> str:
    """Get the weather of a location"""
    return f"It's sunny in {location}"


binded_model = model.bind_tools([get_weather])
response = binded_model.invoke("What is the weather in Chennai?")
# Out:
# []

# %%
response
# Out:
# AIMessage(content=[], additional_kwargs={'function_call': {'name': 'get_weather', 'arguments': '{"location": "Chennai"}'}, '__gemini_function_call_thought_signatures__': {'call_978031': 'El4KXAERTTIP6PXW9B3el3uCFlNDFME79ta+ss3jIkCSksM1/0Qv9eo71+BsJavoLmCzFjs/xbuu2od5tEy3Tewpj1ve5SLvKAPRophS/4JljgAreRulWD0em3eaEm5Y'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a07170-6f3f-77d0-8973-62191ab9a746-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'Chennai'}, 'id': 'call_978031', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 51, 'output_tokens': 16, 'total_tokens': 67, 'input_token_details': {'cache_read': 0}})
